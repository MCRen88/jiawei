# %%
import warnings
warnings.filterwarnings("ignore")
import sys
sys.setrecursionlimit(1000000)
import os
from os import listdir,makedirs
from os.path import join,dirname
import json

import pandas as pd
import numpy as np
from matplotlib.pyplot import cm
import matplotlib.pyplot as plt


from visualize.plot_ts import plot_hist
from feature.feature_anom import *

from utils import savePNG,millisec_to_str
from settings import Config_json, get_user_data_dir, PROJECT_DIR
from curve_list import c
# Out:
# your local data dir prefix is: /Volumes/shihuan/tencent-data/modelflow-data-online-5min/

# %%
root_dir = get_user_data_dir()
clean_list = c
original_path = join(root_dir, "706_dnm_tmp_3ZFwT#sum_iUserNum_300#20190620_16Days_valid6D_pipeline_test_input_node_train_data.csv")
# Out:
# your local data dir prefix is: /Volumes/shihuan/tencent-data/modelflow-data-online-5min/

# %%
df = pd.read_csv(original_path)
df["timestamp"] = df["timestamp"].map(millisec_to_str)

# %%
for l_id in clean_list[:2]:
    df_slice = df[df.line_id == l_id].copy()

# %%
values = df_slice.point.values
n_samples,_ = df_slice.shape
values[-1 ]
train_pnts = 402

# %%
values[-10:]
# Out:
# array([29870., 30851., 32281., 33447., 34380., 35399., 36670., 37504.,
#        38473., 39358.])

# %%
window_size = 288*2
window_samples = []
for indx in range(train_pnts):
    slice_window = values[n_samples - train_pnts + indx + 1 - window_size :n_samples - train_pnts + indx + 1]
    window_samples.append(slice_window)

# %%
np.array(window_samples)
# Out:
# array([[52816., 51406., 49852., ..., 58724., 56865., 54603.],
#        [51406., 49852., 47878., ..., 56865., 54603., 53811.],
#        [49852., 47878., 46044., ..., 54603., 53811., 52395.],
#        ...,
#        [32942., 33829., 34692., ..., 35399., 36670., 37504.],
#        [33829., 34692., 35480., ..., 36670., 37504., 38473.],
#        [34692., 35480., 35996., ..., 37504., 38473., 39358.]])

# %%
feature_list = ["time_series_moving_average",
           "time_series_weighted_moving_average",
           "time_series_exponential_weighted_moving_average",
           "time_series_double_exponential_weighted_moving_average",
#            "time_series_periodic_features", #####append 的问题？？
#            "binned_entropy",
#            "quantile",
#            "change_quantiles",
#            "number_crossing_m",
#            "energy_ratio_by_chunks",
#            "agg_linear_trend",
#            "number_cwt_peaks"
               ]

# %%
    fatures = []
    for sample in samples:
        feature_set = []
        for f in feature_list:
            func = getattr(feature_anom, f)
            print(func)
            format_sample = [[],[],[],[],sample]
            feature_set.append(func(format_sample))
        fatures.append(feature_set)
# Out:
# <function time_series_moving_average at 0x120365488>
# <function time_series_weighted_moving_average at 0x120365510>
# <function time_series_exponential_weighted_moving_average at 0x120365598>
# <function time_series_double_exponential_weighted_moving_average at 0x120365620>
# <function time_series_moving_average at 0x120365488>
# <function time_series_weighted_moving_average at 0x120365510>
# <function time_series_exponential_weighted_moving_average at 0x120365598>
# <function time_series_double_exponential_weighted_moving_average at 0x120365620>
# <function time_series_moving_average at 0x120365488>
# <function time_series_weighted_moving_average at 0x120365510>
# <function time_series_exponential_weighted_moving_average at 0x120365598>
# <function time_series_double_exponential_weighted_moving_average at 0x120365620>
# <function time_series_moving_average at 0x120365488>
# <function time_series_weighted_moving_average at 0x120365510>
# ...

# %%
np.array(fatures).shape
# Out:
# (402, 4)

# %%
 pd.DataFrame(fatures, columns=feature_list)
# Out:
#      time_series_moving_average  time_series_weighted_moving_average  \
# 0                 -10015.504437                         -3697.207820
# 1                  -9221.777007                         -2873.237267
# 2                  -7804.059993                         -1430.180848
# 3                  -5982.804784                           410.561128
# 4                  -3715.058257                          2690.440867
# 5                  -1360.216243                          5050.155107
# 6                    512.448688                          6921.377694
# 7                   2218.919174                          8620.684631
# 8                   3763.665702                         10153.634651
# 9                   5203.467785                         11576.594215
# 10                  6741.820216                         13093.219977
# 11                  8292.058063                         14616.471900
# 12                  9856.190007                         16148.301854
# ...

# %%
fatures = []
for sample in samples:
    feature_set = []
    for f in feature_list:
        func = getattr(feature_anom, f)
        feature_set.append(func( [[],[],[],[],sample]))
    fatures.append(feature_set)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-81-9792418527f9> in <module>
#       4     for f in feature_list:
#       5         func = getattr(feature_anom, f)
# ----> 6         feature_set.append(func( [[],[],[],[],sample]))
#       7     fatures.append(feature_set)
#
# ~/research_space/jiawei/feature/feature_anom.py in time_series_periodic_features(x_list)
#     154     # Add the absolute value of difference between today and yesterday and its sgn as two features
#     155     # '''
# --> 156     temp_value = data_c_left[-1] - data_a[-1]
#     157     periodic_features.append(abs(temp_value))
#     158     if temp_value < 0:
#
# IndexError: list index out of range

# %%
from feature import feature_anom

# %%
sample = window_samples[0]
sample = [[],[],[],[],sample]

# %%
func = getattr(feature_anom, feature_list[0])

# %%
func(sample)
# Out:
# -10015.504437183874

# %%
df_slice[df_slice.timestamp >= "2019-06-20"].shape
# Out:
# (402, 4)

# %%
1440 / 5
# Out:
# 288.0

# %%
from sklearn.metrics import classification_report,confusion_matrix,f1_score,average_precision_score

from sklearn.model_selection import train_test_split


# from time_series_detector.feature.extraction import *
from time_series_detector.algorithm.gbdt import *
import time_series_detector.algorithm.gbdt
# from sklearn.cross_validation import train_test_split
# from data_pre_processing.stable_random_test import model_makesense_determinate
from data_preprocessing.data_format_match import characteristics_format_match
from visualize.plot_ts import anomaly_view, plot_hist
from feature.features_calculate_select 
    import combine_features_calculate,sliding_window, combine_features_calculate\
    , features_selected_ExtraTreesClassifier,selected_columns_names, feature_extraction,cal_features_based_on_id
from visualize.plot_forcast_result import Precision_Recall_Curve, plot_auc, anomaly_predict_view\
    , anomaly_score_view_predict, anomaly_score_view_date
from visualize.plot_stable_view import value_stable_determinate_view
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-56b37c94b346> in <module>()
#       7
#       8 # from time_series_detector.feature.extraction import *
# ----> 9 from time_series_detector.algorithm.gbdt import *
#      10 import time_series_detector.algorithm.gbdt
#      11 # from sklearn.cross_validation import train_test_split
#
# ~/jiawei/time_series_detector/algorithm/gbdt.py in <module>()
#      13 from sklearn.ensemble import GradientBoostingClassifier
#      14 from sklearn.externals import joblib
# ---> 15 from time_series_detector.feature import feature_service
#      16 from time_series_detector.common.tsd_common import *
#      17 from time_series_detector.common.tsd_errorcode import *
#
# ~/jiawei/time_series_detector/feature/feature_service.py in <module>()
#       9 """
#      10 import warnings
# ---> 11 import statistical_features
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-16e830005479> in <module>()
#      15         id_name = selected_id[j]
#      16         id_dataset = total_dataset[total_dataset['line_id'] == id_name]
# ---> 17         cal_features,y_calculate = cal_features_based_on_id(id_dataset,window,id_name)
#      18         selected_calculate_features.append(cal_features)
#      19         selected_label.append(y_calculate)
#
# <ipython-input-12-267cb1c8573c> in cal_features_based_on_id(id_dataset, window, id_name)
#      15     DAY_PNT = len(id_dataset.loc[id_dataset['Date'] == id_dataset['Date'].ix[len(id_dataset)/2]])
#      16     win_sli = window + 7 * DAY_PNT
# ---> 17     x_features_calculate,y_calculate = combine_features_calculate (id_dataset, window,DAY_PNT)
#      18     y_calculate["id"] = id_name
# ...
